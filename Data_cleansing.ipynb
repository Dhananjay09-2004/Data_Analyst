# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r'C:\Users\Welcome\coupon_dataset.csv')

# %%
df
# Out:
#            destination  passanger weather  temperature  time  \
# 0      No Urgent Place      Alone   Sunny           55   2PM
# 1      No Urgent Place  Friend(s)   Sunny           80  10AM
# 2      No Urgent Place  Friend(s)   Sunny           80  10AM
# 3      No Urgent Place  Friend(s)   Sunny           80   2PM
# 4      No Urgent Place  Friend(s)   Sunny           80   2PM
# ...                ...        ...     ...          ...   ...
# 12679             Home    Partner   Rainy           55   6PM
# 12680             Work      Alone   Rainy           55   7AM
# 12681             Work      Alone   Snowy           30   7AM
# 12682             Work      Alone   Snowy           30   7AM
# 12683             Work      Alone   Sunny           80   7AM
#
#                       coupon expiration  gender age      maritalStatus  ...  \
# 0            Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1               Coffee House         2h  Female  21  Unmarried partner  ...
# ...

# %%
len(df)
# Out:
# 12684

# %%
df.head()
# Out:
#        destination  passanger weather  temperature  time  \
# 0  No Urgent Place      Alone   Sunny           55   2PM
# 1  No Urgent Place  Friend(s)   Sunny           80  10AM
# 2  No Urgent Place  Friend(s)   Sunny           80  10AM
# 3  No Urgent Place  Friend(s)   Sunny           80   2PM
# 4  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                   coupon expiration  gender age      maritalStatus  ...  \
# 0        Restaurant(<20)         1d  Female  21  Unmarried partner  ...
# 1           Coffee House         2h  Female  21  Unmarried partner  ...
# 2  Carry out & Take away         2h  Female  21  Unmarried partner  ...
# 3           Coffee House         2h  Female  21  Unmarried partner  ...
# 4           Coffee House         1d  Female  21  Unmarried partner  ...
#
#    CarryAway RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 0        NaN                  4~8              1~3                1
# ...

# %%
df.tail()
# Out:
#       destination passanger weather  temperature time                 coupon  \
# 12679        Home   Partner   Rainy           55  6PM  Carry out & Take away
# 12680        Work     Alone   Rainy           55  7AM  Carry out & Take away
# 12681        Work     Alone   Snowy           30  7AM           Coffee House
# 12682        Work     Alone   Snowy           30  7AM                    Bar
# 12683        Work     Alone   Sunny           80  7AM      Restaurant(20-50)
#
#       expiration gender age maritalStatus  ...  CarryAway  \
# 12679         1d   Male  26        Single  ...        1~3
# 12680         1d   Male  26        Single  ...        1~3
# 12681         1d   Male  26        Single  ...        1~3
# 12682         1d   Male  26        Single  ...        1~3
# 12683         2h   Male  26        Single  ...        1~3
#
#       RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min  \
# 12679                  4~8              1~3                1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   time                  12684 non-null  object
#  5   coupon                12684 non-null  object
#  6   expiration            12684 non-null  object
#  7   gender                12684 non-null  object
#  8   age                   12684 non-null  object
#  9   maritalStatus         12684 non-null  object
#  10  has_children          12684 non-null  int64
#  11  education             12684 non-null  object
#  12  occupation            12684 non-null  object
#  13  income                12684 non-null  object
#  14  car                   108 non-null    object
# ...

# %%
df.describe()
# Out:
#         temperature  has_children  toCoupon_GEQ5min  toCoupon_GEQ15min  \
# count  12684.000000  12684.000000           12684.0       12684.000000
# mean      63.301798      0.414144               1.0           0.561495
# std       19.154486      0.492593               0.0           0.496224
# min       30.000000      0.000000               1.0           0.000000
# 25%       55.000000      0.000000               1.0           0.000000
# 50%       80.000000      0.000000               1.0           1.000000
# 75%       80.000000      1.000000               1.0           1.000000
# max       80.000000      1.000000               1.0           1.000000
#
#        toCoupon_GEQ25min  direction_same  direction_opp             Y  \
# count       12684.000000    12684.000000   12684.000000  12684.000000
# mean            0.119126        0.214759       0.785241      0.568433
# std             0.323950        0.410671       0.410671      0.495314
# ...

# %%
df.isnull().sum()
# Out:
# destination                 0
# passanger                   0
# weather                     0
# temperature                 0
# time                        0
# coupon                      0
# expiration                  0
# gender                      0
# age                         0
# maritalStatus               0
# has_children                0
# education                   0
# occupation                  0
# income                      0
# car                     12576
# Bar                       107
# CoffeeHouse               217
# CarryAway                 151
# RestaurantLessThan20      130
# Restaurant20To50          189
# toCoupon_GEQ5min            0
# toCoupon_GEQ15min           0
# toCoupon_GEQ25min           0
# direction_same              0
# direction_opp               0
# Y                           0
# row_count                   0
# dtype: int64

# %% [markdown]
# it gives % of null values

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# destination              0.000000
# passanger                0.000000
# weather                  0.000000
# temperature              0.000000
# time                     0.000000
# coupon                   0.000000
# expiration               0.000000
# gender                   0.000000
# age                      0.000000
# maritalStatus            0.000000
# has_children             0.000000
# education                0.000000
# occupation               0.000000
# income                   0.000000
# car                     99.148534
# Bar                      0.843582
# CoffeeHouse              1.710817
# CarryAway                1.190476
# RestaurantLessThan20     1.024913
# Restaurant20To50         1.490066
# toCoupon_GEQ5min         0.000000
# toCoupon_GEQ15min        0.000000
# toCoupon_GEQ25min        0.000000
# direction_same           0.000000
# direction_opp            0.000000
# Y                        0.000000
# row_count                0.000000
# dtype: float64

# %%
df.isnull().sum().sum()#how many null value present in the dataset(numbers)
# Out:
# np.int64(13370)

# %%
df.isnull().sum().sum()/(df.shape[0]*df.shape[1])*100
# Out:
# np.float64(3.904014389665604)

# %%
#not null value in dataset
df.notnull().sum()
# Out:
# destination             12684
# passanger               12684
# weather                 12684
# temperature             12684
# time                    12684
# coupon                  12684
# expiration              12684
# gender                  12684
# age                     12684
# maritalStatus           12684
# has_children            12684
# education               12684
# occupation              12684
# income                  12684
# car                       108
# Bar                     12577
# CoffeeHouse             12467
# CarryAway               12533
# RestaurantLessThan20    12554
# Restaurant20To50        12495
# toCoupon_GEQ5min        12684
# toCoupon_GEQ15min       12684
# toCoupon_GEQ25min       12684
# direction_same          12684
# direction_opp           12684
# Y                       12684
# row_count               12684
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# np.int64(329098)

# %% [markdown]
# # this graph represent the how many null values in a dataset

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# #deleting a particluar column

# %%
df.drop(columns=['car'],inplace=True)

# %%
df.shape
# Out:
# (12684, 26)

# %%
#deleting a null value rows
df.dropna(inplace=True)

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
df.isnull().sum()
# Out:
# destination             0
# passanger               0
# weather                 0
# temperature             0
# time                    0
# coupon                  0
# expiration              0
# gender                  0
# age                     0
# maritalStatus           0
# has_children            0
# education               0
# occupation              0
# income                  0
# Bar                     0
# CoffeeHouse             0
# CarryAway               0
# RestaurantLessThan20    0
# Restaurant20To50        0
# toCoupon_GEQ5min        0
# toCoupon_GEQ15min       0
# toCoupon_GEQ25min       0
# direction_same          0
# direction_opp           0
# Y                       0
# row_count               0
# dtype: int64

# %%
df.shape
# Out:
# (12079, 26)

# %% [markdown]
# Handling a missing values

# %%
dataset=pd.read_csv(r'Downloads\country.csv')

# %%
dataset.head()
# Out:
#   S.No. Country or dependency  Population   Area km2 Area sqmi  \
# 0     1           Afghanistan  40,099,462    652,864   252,071
# 1     2       Åland (Finland)      30,344      1,580       610
# 2     3               Albania   2,854,710     28,748    11,100
# 3     4               Algeria  44,177,969  2,381,741   919,590
# 4     5   American Samoa (US)      45,035        199        77
#
#   Population density /km2 Population density /sqmi
# 0                      61                      159
# 1                      19                       50
# 2                      99                      257
# 3                      19                       48
# 4                     226                      586

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(13)

# %%
dataset.fillna('dhananjay')
# Out:
#                                    S.No. Country or dependency  Population  \
# 0                                      1           Afghanistan  40,099,462
# 1                                      2       Åland (Finland)      30,344
# 2                                      3               Albania   2,854,710
# 3                                      4               Algeria  44,177,969
# 4                                      5   American Samoa (US)      45,035
# ..                                   ...                   ...         ...
# 245                                  246                 Yemen  32,981,641
# 246                                  247                Zambia  19,473,125
# 247                                  248              Zimbabwe  15,993,524
# 248                            dhananjay             dhananjay   dhananjay
# 249  https://www.downloadexcelfiles.com/             dhananjay   dhananjay
#
# ...

# %%
dataset.fillna(method="bfill") #backward data filling
# Out:
# C:\Users\Welcome\AppData\Local\Temp\ipykernel_13728\3208040168.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="bfill") #backward data filling
#                                    S.No. Country or dependency  Population  \
# 0                                      1           Afghanistan  40,099,462
# 1                                      2       Åland (Finland)      30,344
# 2                                      3               Albania   2,854,710
# 3                                      4               Algeria  44,177,969
# 4                                      5   American Samoa (US)      45,035
# ..                                   ...                   ...         ...
# 245                                  246                 Yemen  32,981,641
# 246                                  247                Zambia  19,473,125
# ...

# %%
dataset.select_dtypes(include="object")
# Out:
#                                    S.No. Country or dependency  Population  \
# 0                                      1           Afghanistan  40,099,462
# 1                                      2       Åland (Finland)      30,344
# 2                                      3               Albania   2,854,710
# 3                                      4               Algeria  44,177,969
# 4                                      5   American Samoa (US)      45,035
# ..                                   ...                   ...         ...
# 245                                  246                 Yemen  32,981,641
# 246                                  247                Zambia  19,473,125
# 247                                  248              Zimbabwe  15,993,524
# 248                                  NaN                   NaN         NaN
# 249  https://www.downloadexcelfiles.com/                   NaN         NaN
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   S.No.                     249 non-null    object
#  1   Country or dependency     248 non-null    object
#  2   Population                248 non-null    object
#  3   Area km2                  248 non-null    object
#  4   Area sqmi                 248 non-null    object
#  5   Population density /km2   248 non-null    object
#  6   Population density /sqmi  248 non-null    object
# dtypes: object(7)
# memory usage: 13.8+ KB

# %% [markdown]
# Handling missing values in scikit learn

# %%
from sklearn.impute import SimpleImputer

# %%
dataset.columns
# Out:
# Index(['S.No.', 'Country or dependency', 'Population', 'Area km2', 'Area sqmi',
#        'Population density /km2', 'Population density /sqmi'],
#       dtype='object')

# %%
si=SimpleImputer(strategy="mean")
si.fit_transform(dataset[['S.No.', 'Country or dependency', 'Population', 'Area km2', 'Area sqmi',
       'Population density /km2', 'Population density /sqmi']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 2
#       1 si=SimpleImputer(strategy="mean")
# ----> 2 si.fit_transform(dataset[['S.No.', 'Country or dependency', 'Population', 'Area km2', 'Area sqmi',
#       3        'Population density /km2', 'Population density /sqmi']])
#
# File ~\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\_set_output.py:316, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     314 @wraps(f)
#     315 def wrapped(self, X, *args, **kwargs):
# --> 316     data_to_wrap = f(self, X, *args, **kwargs)
#     317     if isinstance(data_to_wrap, tuple):
#     318         # only wrap the first output for cross decomposition
#     319         return_tuple = (
#     320             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     321             *data_to_wrap[1:],
#     322         )
#
# ...

# %%
dataset=dataset.rename(columns={'Area km2':'Areakm"})

# %%
df.info()

# %%
df.select_dtypes(include="int64").columns

# %%
#fill the null values  using sikitlearn

# %%
si=SimpleImputer(strategy="mean")
ar=si.fit_transform(df[['temperature', 'has_children', 'toCoupon_GEQ5min', 'toCoupon_GEQ15min',
       'toCoupon_GEQ25min', 'direction_same', 'direction_opp', 'Y',
       'row_count']])

# %%
new_dataset=pd.DataFrame(ar,columns=df.select_dtypes(include="int64").columns)

# %%
new_dataset.isnull().sum()

# %%
new_dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 new_dataset
#
# NameError: name 'new_dataset' is not defined

# %% [markdown]
# onehot enconding

# %%
ds=pd.DataFrame({"name":["Dhananjay","Rahul","Sagar","santosh","Ram"]})

# %%
ds
# Out:
#         name
# 0  Dhananjay
# 1      Rahul
# 2      Sagar
# 3    santosh
# 4        Ram

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
ds["en_name"]=le.fit_transform(ds[["name"]])
# Out:
# C:\Users\Welcome\AppData\Roaming\Python\Python313\site-packages\sklearn\preprocessing\_label.py:110: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
ds
# Out:
#         name  en_name
# 0  Dhananjay        0
# 1      Rahul        1
# 2      Sagar        3
# 3    santosh        4
# 4        Ram        2

# %% [markdown]
# #outlier

# %%
dataset.head()
# Out:
#   S.No. Country or dependency  Population   Area km2 Area sqmi  \
# 0     1           Afghanistan  40,099,462    652,864   252,071
# 1     2       Åland (Finland)      30,344      1,580       610
# 2     3               Albania   2,854,710     28,748    11,100
# 3     4               Algeria  44,177,969  2,381,741   919,590
# 4     5   American Samoa (US)      45,035        199        77
#
#   Population density /km2 Population density /sqmi
# 0                      61                      159
# 1                      19                       50
# 2                      99                      257
# 3                      19                       48
# 4                     226                      586

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   S.No.                     249 non-null    object
#  1   Country or dependency     248 non-null    object
#  2   Population                248 non-null    object
#  3   Area km2                  248 non-null    object
#  4   Area sqmi                 248 non-null    object
#  5   Population density /km2   248 non-null    object
#  6   Population density /sqmi  248 non-null    object
# dtypes: object(7)
# memory usage: 13.8+ KB

# %%
dataset.isnull().sum()
# Out:
# S.No.                       1
# Country or dependency       2
# Population                  2
# Area km2                    2
# Area sqmi                   2
# Population density /km2     2
# Population density /sqmi    2
# dtype: int64

# %%
dataset.describe()
# Out:
#        S.No. Country or dependency  Population Area km2 Area sqmi  \
# count    249                   248         248      248       248
# unique   249                   248         248      247       240
# top        1           Afghanistan  40,099,462       21         5
# freq       1                     1           1        2         3
#
#        Population density /km2 Population density /sqmi
# count                      248                      248
# unique                     173                      210
# top                          4                       43
# freq                         8                        5

# %%
sns.boxplot(x="Area sqmi",data=dataset)
plt.show()

# %%
df.head()
# Out:
#         destination  passanger weather  temperature  time  \
# 22  No Urgent Place      Alone   Sunny           55   2PM
# 23  No Urgent Place  Friend(s)   Sunny           80  10AM
# 24  No Urgent Place  Friend(s)   Sunny           80  10AM
# 25  No Urgent Place  Friend(s)   Sunny           80  10AM
# 26  No Urgent Place  Friend(s)   Sunny           80   2PM
#
#                    coupon expiration gender age maritalStatus  ...  CarryAway  \
# 22        Restaurant(<20)         1d   Male  21        Single  ...        4~8
# 23           Coffee House         2h   Male  21        Single  ...        4~8
# 24                    Bar         1d   Male  21        Single  ...        4~8
# 25  Carry out & Take away         2h   Male  21        Single  ...        4~8
# 26           Coffee House         1d   Male  21        Single  ...        4~8
#
#    RestaurantLessThan20 Restaurant20To50 toCoupon_GEQ5min toCoupon_GEQ15min  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12079 entries, 22 to 12683
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12079 non-null  object
#  1   passanger             12079 non-null  object
#  2   weather               12079 non-null  object
#  3   temperature           12079 non-null  int64
#  4   time                  12079 non-null  object
#  5   coupon                12079 non-null  object
#  6   expiration            12079 non-null  object
#  7   gender                12079 non-null  object
#  8   age                   12079 non-null  object
#  9   maritalStatus         12079 non-null  object
#  10  has_children          12079 non-null  int64
#  11  education             12079 non-null  object
#  12  occupation            12079 non-null  object
#  13  income                12079 non-null  object
#  14  Bar                   12079 non-null  object
# ...

# %%
sns.boxplot(x="passanger",data=df)
plt.show()

# %%
df.
# Out:
#   Cell In[79], line 1
#     df.
#        ^
# SyntaxError: invalid syntax

# %%
sns.displot(df["temperature"])

# %% [markdown]
# #outlier romovel using iqr

# %%
d1=df["temperature"].quantile(0.25)
d2=df["temperature"].quantile(0.75)

# %%
d1
d2

# %%
d2

# %%
d1

# %%
iqr=d2-d1

# %% [markdown]
# max_range=d1-(1.5*iqr)
# min_range=d2+(1.5*iqr)

# %%
max_range=d1-(1.5*iqr)
min_range=d2+(1.5*iqr)

# %%
max_range

# %%
min_range

# %%
new_data=df[df["temperature"]<=max_range]

# %%
new_data.shape

# %%
df.shape

# %%
sns.boxplot(x="temperature",data=new_data)
plt.show()

# %%
sns.boxplot(x="row_count",data=df)

# %% [markdown]
# How Can Duplicate Data Handle And Remove

# %%
df5 = pd.read_csv(r'Downloads\train.csv')

# %%
df5
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data={"name":['a','b','c','d','a'],"hindhi":[2,4,5,6,2],"english":[2,45,5,3,2]}

# %%
df6=pd.DataFrame(data)

# %%
df6
# Out:
#   name  hindhi  english
# 0    a       2        2
# 1    b       4       45
# 2    c       5        5
# 3    d       6        3
# 4    a       2        2

# %%
df6["duplicate"]=df6.duplicated()

# %%
df6
# Out:
#   name  hindhi  english  duplicate
# 0    a       2        2      False
# 1    b       4       45      False
# 2    c       5        5      False
# 3    d       6        3      False
# 4    a       2        2       True

# %%
df6.drop_duplicates(inplace=True)

# %%
df6
# Out:
#   name  hindhi  english  duplicate
# 0    a       2        2      False
# 1    b       4       45      False
# 2    c       5        5      False
# 3    d       6        3      False
# 4    a       2        2       True

# %%
df5.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 550063    False
# 550064    False
# 550065    False
# 550066    False
# 550067    False
# Length: 550068, dtype: bool

# %%
df5.drop_duplicates(inplace=True)

# %%
df5.shape
# Out:
# (550068, 12)

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
sns.displot(df5["Product_Category_1"])
plt.show()
