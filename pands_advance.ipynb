# %%
import pandas as pd

# %%
movie=pd.read_csv(r'C:\Users\Welcome\Downloads\movie.csv')

# %%
movie
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
rating=pd.read_csv(r'C:\Users\Welcome\Downloads\rating.csv')

# %%
rating
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
rating
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
tag=pd.read_csv(r'C:\Users\Welcome\Downloads\tag.csv')

# %%
tag
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tag.head(23)
# Out:
#     userId  movieId                tag            timestamp
# 0       18     4141        Mark Waters  2009-04-24 18:19:40
# 1       65      208          dark hero  2013-05-10 01:41:18
# 2       65      353          dark hero  2013-05-10 01:41:19
# 3       65      521      noir thriller  2013-05-10 01:39:43
# 4       65      592          dark hero  2013-05-10 01:41:18
# 5       65      668          bollywood  2013-05-10 01:37:56
# 6       65      898   screwball comedy  2013-05-10 01:42:40
# 7       65     1248      noir thriller  2013-05-10 01:39:43
# 8       65     1391               mars  2013-05-10 01:40:55
# 9       65     1617           neo-noir  2013-05-10 01:43:37
# 10      65     1694              jesus  2013-05-10 01:38:45
# 11      65     1783      noir thriller  2013-05-10 01:39:43
# 12      65     2022              jesus  2013-05-10 01:38:45
# 13      65     2193             dragon  2013-05-10 02:01:54
# 14      65     2353  conspiracy theory  2013-05-10 02:01:06
# ...

# %%
row_0=tag.iloc[1]    #here tag used for this file name is tag
type(row_0)
# Out:
# pandas.core.series.Series

# %%
print(row_0)
# Out:
# userId                        65
# movieId                      208
# tag                    dark hero
# timestamp    2013-05-10 01:41:18
# Name: 1, dtype: object

# %%
row_0['userId']
# Out:
# np.int64(65)

# %% [raw]
# 'rating' in row_0

# %%
rating.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
del rating['timestamp']

# %%
rating
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
row_0['userId']
# Out:
# np.int64(65)

# %%
'rating' in row_0
# Out:
# False

# %%
print(rating)
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
#rename first roe
row_0 = row_0.rename('firstRow')
row_0.name
# Out:
# 'firstRow'

# %%
rating
# Out:
#           userId  movieId  rating
# 0              1        2     3.5
# 1              1       29     3.5
# 2              1       32     3.5
# 3              1       47     3.5
# 4              1       50     3.5
# ...          ...      ...     ...
# 20000258  138493    68954     4.5
# 20000259  138493    69526     4.5
# 20000260  138493    69644     3.0
# 20000261  138493    70286     5.0
# 20000262  138493    71619     2.5
#
# [20000263 rows x 3 columns]

# %%
#prirnt column names

# %%
tag.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
#print index location
tag.iloc[ [0,11,500] ]
# Out:
#      userId  movieId                tag            timestamp
# 0        18     4141        Mark Waters  2009-04-24 18:19:40
# 11       65     1783      noir thriller  2013-05-10 01:39:43
# 500     342    55908  entirely dialogue  2012-01-31 18:41:16

# %%
#rating mean function used
rating['rating'].mean()
# Out:
# np.float64(3.5255285642993797)

# %%
#rating min
rating['rating'].min()
# Out:
# 0.5

# %%
#rating max
rating['rating'].max()
# Out:
# 5.0

# %%
#pairwise correlation
rating.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
filter1 = rating['rating'] > 10
print(filter1)
filter1.any()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# np.False_

# %%
filter1 = rating['rating'] > 10
print(filter1)
filter1.all()
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool
# np.False_

# %%
# %matplotlib inline

a1=rating.hist(column='rating', figsize=(10,5))

# %%
a1
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
plt.show(a1)

# %%
a2=rating.boxplot(column='rating', figsize=(10,5))

# %%
plt.show(a2)

# %%
a3=tag_count[:10].plot(kind='bar', figsize=(10,5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 a3=tag_count[:10].plot(kind='bar', figsize=(10,5))
#
# NameError: name 'tag_count' is not defined

# %%
plt.show(a3)

# %%
ag_counts = tag['tag'].value_counts()
ag_counts[-10:]
# Out:
# tag
# Hell naw                      1
# This is my happy face         1
# I heel toe on Uday's house    1
# Why?                          1
# Bobo                          1
# Diamond Dallas Page           1
# I'm Devon Butler!             1
# No arguement                  1
# Really Bad                    1
# Botox                         1
# Name: count, dtype: int64

# %%
movies_genres = movie['genres'].str.split('|', expand=True)

# %%
movies_genres[:10]
# Out:
#            0          1         2       3        4     5     6     7     8  \
# 0  Adventure  Animation  Children  Comedy  Fantasy  None  None  None  None
# 1  Adventure   Children   Fantasy    None     None  None  None  None  None
# 2     Comedy    Romance      None    None     None  None  None  None  None
# 3     Comedy      Drama   Romance    None     None  None  None  None  None
# 4     Comedy       None      None    None     None  None  None  None  None
# 5     Action      Crime  Thriller    None     None  None  None  None  None
# 6     Comedy    Romance      None    None     None  None  None  None  None
# 7  Adventure   Children      None    None     None  None  None  None  None
# 8     Action       None      None    None     None  None  None  None  None
# 9     Action  Adventure  Thriller    None     None  None  None  None  None
#
#       9
# 0  None
# 1  None
# 2  None
# 3  None
# 4  None
# 5  None
# 6  None
# 7  None
# 8  None
# 9  None
