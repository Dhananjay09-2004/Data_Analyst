# %%
import pandas as pd

# %%
data=pd.read_csv(r'D:\New folder\Movies\movies_500.csv')

# %%
data
# Out:
#                       Film        Genre  RottenTomatoesRating%  \
# 0    Falling River Returns     Thriller                     60
# 1            Neon Dream II     Thriller                     29
# 2              First Trial    Animation                     64
# 3               Iron Storm     Thriller                     43
# 4           Golden Horizon        Drama                     51
# ..                     ...          ...                    ...
# 495          Falling Field  Documentary                     50
# 496   Falling World Reborn       Action                     41
# 497          Burning Quest        Drama                     56
# 498          Bright Signal    Adventure                     59
# 499         Lost House III  Documentary                     54
#
#      AudienceRating%  Budget(million$)  YearOfRelease
# 0                 64              26.8           1994
# 1                 26              28.3           1994
# ...

# %%
data.head()
# Out:
#                     Film      Genre  RottenTomatoesRating%  AudienceRating%  \
# 0  Falling River Returns   Thriller                     60               64
# 1          Neon Dream II   Thriller                     29               26
# 2            First Trial  Animation                     64               79
# 3             Iron Storm   Thriller                     43               52
# 4         Golden Horizon      Drama                     51               36
#
#    Budget(million$)  YearOfRelease
# 0              26.8           1994
# 1              28.3           1994
# 2              87.8           2006
# 3              45.0           2001
# 4              11.7           1982

# %%
len(data)
# Out:
# 500

# %%
data.columns
# Out:
# Index(['Film', 'Genre', 'RottenTomatoesRating%', 'AudienceRating%',
#        'Budget(million$)', 'YearOfRelease'],
#       dtype='object')

# %%
data.shape
# Out:
# (500, 6)

# %%
data.columns=['Film','Genre','criticRating','AudienceRating','Budget','Year']

# %%
data
# Out:
#                       Film        Genre  criticRating  AudienceRating  Budget  \
# 0    Falling River Returns     Thriller            60              64    26.8
# 1            Neon Dream II     Thriller            29              26    28.3
# 2              First Trial    Animation            64              79    87.8
# 3               Iron Storm     Thriller            43              52    45.0
# 4           Golden Horizon        Drama            51              36    11.7
# ..                     ...          ...           ...             ...     ...
# 495          Falling Field  Documentary            50              67     6.6
# 496   Falling World Reborn       Action            41              43    55.4
# 497          Burning Quest        Drama            56              46     0.5
# 498          Bright Signal    Adventure            59              54    80.8
# 499         Lost House III  Documentary            54              69     0.2
#
#      Year
# 0    1994
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            500 non-null    object
#  1   Genre           500 non-null    object
#  2   criticRating    500 non-null    int64
#  3   AudienceRating  500 non-null    int64
#  4   Budget          500 non-null    float64
#  5   Year            500 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 23.6+ KB

# %%
data.describe()
# Out:
#        criticRating  AudienceRating      Budget         Year
# count    500.000000      500.000000  500.000000   500.000000
# mean      55.224000       55.202000   41.835800  2000.520000
# std       20.314013       23.611187   44.257618    12.665007
# min        5.000000        1.000000    0.200000  1980.000000
# 25%       41.000000       37.000000    8.475000  1989.000000
# 50%       56.000000       54.000000   26.700000  2000.000000
# 75%       69.250000       72.000000   60.925000  2012.000000
# max      100.000000      100.000000  206.900000  2022.000000

# %% [markdown]
# #astype function use change the data  type

# %%
data.Film=data.Film.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            500 non-null    category
#  1   Genre           500 non-null    object
#  2   criticRating    500 non-null    int64
#  3   AudienceRating  500 non-null    int64
#  4   Budget          500 non-null    float64
#  5   Year            500 non-null    int64
# dtypes: category(1), float64(1), int64(3), object(1)
# memory usage: 40.7+ KB

# %%
data.head()
# Out:
#                     Film      Genre  criticRating  AudienceRating  Budget  \
# 0  Falling River Returns   Thriller            60              64    26.8
# 1          Neon Dream II   Thriller            29              26    28.3
# 2            First Trial  Animation            64              79    87.8
# 3             Iron Storm   Thriller            43              52    45.0
# 4         Golden Horizon      Drama            51              36    11.7
#
#    Year
# 0  1994
# 1  1994
# 2  2006
# 3  2001
# 4  1982

# %%
data.Genre=data.Genre.astype('category')
data.Year=data.Year.astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            500 non-null    category
#  1   Genre           500 non-null    category
#  2   criticRating    500 non-null    int64
#  3   AudienceRating  500 non-null    int64
#  4   Budget          500 non-null    float64
#  5   Year            500 non-null    category
# dtypes: category(3), float64(1), int64(2)
# memory usage: 35.9 KB

# %%
data.head()
# Out:
#                     Film      Genre  criticRating  AudienceRating  Budget  \
# 0  Falling River Returns   Thriller            60              64    26.8
# 1          Neon Dream II   Thriller            29              26    28.3
# 2            First Trial  Animation            64              79    87.8
# 3             Iron Storm   Thriller            43              52    45.0
# 4         Golden Horizon      Drama            51              36    11.7
#
#    Year
# 0  1994
# 1  1994
# 2  2006
# 3  2001
# 4  1982

# %%
data.describe()
# Out:
#        criticRating  AudienceRating      Budget
# count    500.000000      500.000000  500.000000
# mean      55.224000       55.202000   41.835800
# std       20.314013       23.611187   44.257618
# min        5.000000        1.000000    0.200000
# 25%       41.000000       37.000000    8.475000
# 50%       56.000000       54.000000   26.700000
# 75%       69.250000       72.000000   60.925000
# max      100.000000      100.000000  206.900000

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
j=sns.jointplot(data=data,x='criticRating',y='AudienceRating',kind='hex')

# %%
plt.show(j)

# %%
j=sns.jointplot(data=data,x='criticRating',y='AudienceRating',kind='reg')

# %%
plt.show(j)

# %%
j=sns.jointplot(data=data,x='criticRating',y='AudienceRating',)

# %%
plt.show(j)

# %%
m1=sns.displot(data.AudienceRating)

# %%
plt.show(m1)

# %%
m1=sns.displot(data.criticRating)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Film            500 non-null    category
#  1   Genre           500 non-null    category
#  2   criticRating    500 non-null    int64
#  3   AudienceRating  500 non-null    int64
#  4   Budget          500 non-null    float64
#  5   Year            500 non-null    category
# dtypes: category(3), float64(1), int64(2)
# memory usage: 35.9 KB

# %%
plt.show(m1)

# %% [markdown]
# #this fuction used for change the background  color

# %%
sns.set_style('darkgrid')

# %%
m2=sns.displot(data.AudienceRating,bins=20)

# %%
plt.show(m2)

# %%
n1=plt.hist(data.AudienceRating,bins=20)

# %%
plt.show(n1)

# %%
sns.set_style('white')

# %%
n1=plt.hist(data.criticRating ,bins=20)

# %%
plt.show(n1)

# %%
plt.hist(data.Budget)
plt.show()

# %%
vis1=sns.lmplot(data=data,x='criticRating',y='AudienceRating',fit_reg=True,hue='Genre')

# %%
plt.show(vis1)

# %%
plt.show(k1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.show(k1)
#
# NameError: name 'k1' is not defined

# %%
import os

# %%
k1=sns.kdeplot(data=data,x='AudienceRating',y='criticRating',color='Red',fill=True)

# %%
plt.show(k1)

# %%
sns.set_style('dark')

# %%
k1=sns.kdeplot(data=data,x='AudienceRating',y='criticRating',color='Green',fill=True,shade=True,shade_lowest=False)

# %%
plt.show(k1)

# %%
data.info()

# %%
k1=sns.kdeplot(data=data,x='Budget',y='criticRating',color='Green',fill=True,shade=True,shade_lowest=False)

# %%
plt.show(k1)

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

# %%
plt.show()

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
k1=sns.kdeplot(data=data,x='Budget',y='criticRating',ax=axes[0])
k2=sns.kdeplot(data=data,x='Budget',y='criticRating',ax=axes[1])

# %%
plt.show()

# %%
w=sns.boxplot(data=data,x='Genre',y='criticRating')

# %%
plt.show(w)

# %%
z=sns.violinplot(data=data,x='Genre',y='criticRating')

# %%
plt.show(z)

# %%
plt.show(w1)

# %%
w1=sns.boxplot(data=data,x='Genre',y='AudienceRating')

# %%
g=sns.FacetGrid(data,row='Genre',col='Year',hue='Genre')

# %%
plt.show(g)

# %%
plt.scatter(data=data,x='critcsRating',y='AudienceRating')

# %%
plt.show()

# %%
g=sns.FacetGrid(data,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'critcsRating''AudienceRating')

# %%
sns.set_style('dark',{'axes.facecolor':'black'})
fig, axes = plt.subplots(nrows=2, ncols=2)
k1=plt.boxplot(data=data,x='Budget',y='criticRating',color='Green',fill=True,shade=True,shade_lowest=False,ax=axes[0,0])
w1=sns.boxplot(data=data,x='Genre',y='AudienceRating')
z=sns.violinplot(data=data,x='Genre',y='criticRating',ax=axes[1,1])


k1.set(xlim=(-20,160))

k2.set(xlim=(-20,160))
plt.show()

# %%
plt.show()
